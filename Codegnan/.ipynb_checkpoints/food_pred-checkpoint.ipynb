# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('dataset.csv')

data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
data.isnull()
# Out:
#        Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0    False   False           False       False           False
# 1    False   False           False       False           False
# 2    False   False           False       False           False
# 3    False   False           False       False           False
# 4    False   False           False       False           False
# ..     ...     ...             ...         ...             ...
# 383  False   False           False       False           False
# 384  False   False           False       False           False
# 385  False   False           False       False           False
# 386  False   False           False       False           False
# 387  False   False           False       False           False
#
#      Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                         False        False     False      False     False
# ...

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
data.describe().corr()
# Out:
#                   Age  Family size  latitude  longitude  Pin code
# Age          1.000000     0.998314  0.999202   0.984153 -0.608483
# Family size  0.998314     1.000000  0.999523   0.973710 -0.650710
# latitude     0.999202     0.999523  1.000000   0.979980 -0.628335
# longitude    0.984153     0.973710  0.979980   1.000000 -0.460870
# Pin code    -0.608483    -0.650710 -0.628335  -0.460870  1.000000

# %%
data['Age'],data['Family size'],data['Occupation'],data['Monthly Income'],data['Feedback']
# Out:
# (0      20
#  1      24
#  2      22
#  3      22
#  4      22
#         ..
#  383    23
#  384    23
#  385    22
#  386    23
#  387    23
#  Name: Age, Length: 388, dtype: int64,
#  0      4
#  1      3
#  2      3
#  3      6
#  4      4
#        ..
#  383    2
#  384    4
#  385    5
#  386    2
#  387    5
#  Name: Family size, Length: 388, dtype: int64,
#  0      Student
#  1      Student
#  2      Student
#  3      Student
#  4      Student
#          ...
#  383    Student
#  384    Student
#  385    Student
#  386    Student
#  387    Student
#  Name: Occupation, Length: 388, dtype: object,
#  0           No Income
#  1      Below Rs.10000
#  2      Below Rs.10000
#  3           No Income
#  4      Below Rs.10000
#              ...
#  383         No Income
#  384         No Income
#  385         No Income
#  386    Below Rs.10000
#  387         No Income
#  Name: Monthly Income, Length: 388, dtype: object,
#  0       Positive
#  1       Positive
#  2      Negative
# ...

# %%
data['Gender'].unique().sum(),data['Gender'].value_counts()
# Out:
# ('FemaleMale',
#  Gender
#  Male      222
#  Female    166
#  Name: count, dtype: int64)

# %%
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
data['Age'].value_counts(),data['Occupation'].value_counts()
# Out:
# (Age
#  23    73
#  22    57
#  25    52
#  24    50
#  26    35
#  21    23
#  27    21
#  32    16
#  28    15
#  29    14
#  20     9
#  30     9
#  31     8
#  19     4
#  18     1
#  33     1
#  Name: count, dtype: int64,
#  Occupation
#  Student           207
#  Employee          118
#  Self Employeed     54
#  House wife          9
#  Name: count, dtype: int64)

# %%
plt.pie(data['Occupation'].value_counts())
plt.show()

# %%
data['Gender'].value_counts().plot(kind='pie')
plt.show()

# %%
data['Occupation'].value_counts().plot(kind='bar')
plt.show()

# %%
import sklearn

# %%
data['Output'].value_counts().plot(kind='bar')
plt.show()

# %%
# data["Gender"] = data["Gender"].map({"Male": 1,"Female": 0})

# data["Marital Status"] = data["Marital Status"].map({"Married": 2,"Single": 1,"Prefer not to say": 0})

# data["Occupation"] = data["Occupation"].map({"Student": 1,"Employee": 2,"Self Employeed": 3,"House wife": 4})

# data["Educational Qualifications"] = data["Educational Qualifications"].map({"Graduate": 1,"Post Graduate": 2,"Ph.D": 3, "School": 4,"Uneducated": 5})

# data["Monthly Income"] = data["Monthly Income"].map({"No Income": 0,"25001 to 50000": 5000,"More than 50000": 7000,"10001 to 25000": 25000,"Below Rs.10000": 10000})

# data["Feedback"] = data["Feedback"].map({"Positive": 1,"Negative ": 0})

# data["Output"] = data["Output"].map({"Yes": 1,"No": 0})

# %%
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

data['Output'] = encoder.fit_transform(data['Output'])

e_o = dict(zip(encoder.transform(encoder.classes_),encoder.classes_))

for i,j in e_o.items():
    print(f'{i} - {j}')
# Out:
# 0 - No
# 1 - Yes

# %%
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
data['Monthly Income'] = encoder.fit_transform(data['Monthly Income'])

e_o = dict(zip(encoder.transform(encoder.classes_),encoder.classes_))

for i,j in e_o.items():
    print(f'{i} - {j}')
# Out:
# 0 - 10001 to 25000
# 1 - 25001 to 50000
# 2 - Below Rs.10000
# 3 - More than 50000
# 4 - No Income

# %%
data['Gender'] = encoder.fit_transform(data['Gender'])

e_o = dict(zip(encoder.transform(encoder.classes_),encoder.classes_))

for i,j in e_o.items():
    print(f'{i} - {j}')

data['Occupation'] = encoder.fit_transform(data['Occupation'])

e_o = dict(zip(encoder.transform(encoder.classes_),encoder.classes_))

for i,j in e_o.items():
    print(f'{i} - {j}')

data['Educaitonal Qualifications'] = encoder.fit_transform(data['Educational Qualifications'])

e_o = dict(zip(encoder.transform(encoder.classes_),encoder.classes_))

for i,j in e_o.items():
    print(f'{i} - {j}')

data['Marital Status'] = encoder.fit_transform(data['Marital Status'])

e_o = dict(zip(encoder.transform(encoder.classes_),encoder.classes_))

for i,j in e_o.items():
    print(f'{i} - {j}')
# Out:
# 0 - Female
# 1 - Male
# 0 - Employee
# 1 - House wife
# 2 - Self Employeed
# 3 - Student
# 0 - Graduate
# 1 - Ph.D
# 2 - Post Graduate
# 3 - School
# 4 - Uneducated
# 0 - Married
# 1 - Prefer not to say
# 2 - Single

# %%
data
# Out:
#      Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0     20       0               2           3               4
# 1     24       0               2           3               2
# 2     22       1               2           3               2
# 3     22       0               2           3               4
# 4     22       1               2           3               2
# ..   ...     ...             ...         ...             ...
# 383   23       0               2           3               4
# 384   23       0               2           3               4
# 385   22       0               2           3               4
# 386   23       1               2           3               2
# 387   23       1               2           3               4
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
data['Educational Qualifications'] = encoder.fit_transform(data['Educational Qualifications'])

e_o = dict(zip(encoder.transform(encoder.classes_),encoder.classes_))

for i,j in e_o.items():
    print(f'{i} - {j}')
# Out:
# 0 - Graduate
# 1 - Ph.D
# 2 - Post Graduate
# 3 - School
# 4 - Uneducated

# %%
data
# Out:
#      Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0     20       0               2           3               4
# 1     24       0               2           3               2
# 2     22       1               2           3               2
# 3     22       0               2           3               4
# 4     22       1               2           3               2
# ..   ...     ...             ...         ...             ...
# 383   23       0               2           3               4
# 384   23       0               2           3               4
# 385   22       0               2           3               4
# 386   23       1               2           3               2
# 387   23       1               2           3               4
#
#      Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                             2            4   12.9766    77.5993    560001
# 1                             0            3   12.9770    77.5773    560009
# ...

# %%
data.drop('latitude',axis=1,inplace=True)

# %%
data.drop('longitude',axis=1,inplace=True)

# %%
data.drop(['Unnamed: 12','Pin code'], axis=1,inplace=True)

# %%
data
# Out:
#      Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0     20       0               2           3               4
# 1     24       0               2           3               2
# 2     22       1               2           3               2
# 3     22       0               2           3               4
# 4     22       1               2           3               2
# ..   ...     ...             ...         ...             ...
# 383   23       0               2           3               4
# 384   23       0               2           3               4
# 385   22       0               2           3               4
# 386   23       1               2           3               2
# 387   23       1               2           3               4
#
#      Educational Qualifications  Family size  Output   Feedback  \
# 0                             2            4       1   Positive
# 1                             0            3       1   Positive
# ...

# %%
data['Feedback'] = encoder.fit_transform(data['Feedback'])

e_o = dict(zip(encoder.transform(encoder.classes_),encoder.classes_))

for i,j in e_o.items():
    print(f'{i} - {j}')
# Out:
# 0 - Negative
# 1 - Positive

# %%
data
# Out:
#      Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0     20       0               2           3               4
# 1     24       0               2           3               2
# 2     22       1               2           3               2
# 3     22       0               2           3               4
# 4     22       1               2           3               2
# ..   ...     ...             ...         ...             ...
# 383   23       0               2           3               4
# 384   23       0               2           3               4
# 385   22       0               2           3               4
# 386   23       1               2           3               2
# 387   23       1               2           3               4
#
#      Educational Qualifications  Family size  Output  Feedback  \
# 0                             2            4       1         1
# 1                             0            3       1         1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    int32
#  2   Marital Status              388 non-null    int32
#  3   Occupation                  388 non-null    int32
#  4   Monthly Income              388 non-null    int32
#  5   Educational Qualifications  388 non-null    int32
#  6   Family size                 388 non-null    int64
#  7   Output                      388 non-null    int32
#  8   Feedback                    388 non-null    int32
#  9   Educaitonal Qualifications  388 non-null    int32
# dtypes: int32(8), int64(2)
# memory usage: 18.3 KB

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
x = data.drop('Output',axis=1)
y = data['Output']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2,random_state=123)
